# %%
import pandas as pd
import numpy as np

# %%
pymoli = "../purchase_data.json"

# %%
pymoli2_pd = pd.read_json(pymoli)
pymoli2_pd.head(780)
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# ...

# %%
pymoli2_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 780 entries, 0 to 779
# Data columns (total 6 columns):
# Age          780 non-null int64
# Gender       780 non-null object
# Item ID      780 non-null int64
# Item Name    780 non-null object
# Price        780 non-null float64
# SN           780 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 42.7+ KB

# %%
playercount = pymoli2_pd.groupby('SN')
playercount2 = len(playercount)
playercount2
# Out:
# 573

# %%
item = pymoli2_pd.groupby('Item Name')
item2 = len(item)
item2
# Out:
# 179

# %%
average_price = pymoli2_pd['Price'].mean()
average_price
# Out:
# 2.931192307692303

# %%
total_count = pymoli2_pd.count()
total_count
# Out:
# Age          780
# Gender       780
# Item ID      780
# Item Name    780
# Price        780
# SN           780
# dtype: int64

# %%
total_revenue = pymoli2_pd['Price'].sum()
total_revenue
# Out:
# 2286.3299999999963

# %%
male_purchases_pd = pymoli2_pd.loc[pymoli2_pd["Gender"] == "Male"]
male_purchases_pd
# Out:
#      Age Gender  Item ID                                  Item Name  Price  \
# 0     38   Male      165                Bone Crushing Silver Skewer   3.37
# 1     21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2     34   Male      174                            Primitive Blade   2.46
# 3     21   Male       92                               Final Critic   1.36
# 4     23   Male       63                             Stormfury Mace   1.27
# 5     20   Male       10                                Sleepwalker   1.73
# 6     20   Male      153                            Mercenary Sabre   4.57
# 8     25   Male      118           Ghost Reaver, Longsword of Magic   2.77
# 9     31   Male       99       Expiration, Warscythe Of Lost Worlds   4.53
# 10    24   Male       57            Despair, Favor of Due Diligence   3.81
# 11    20   Male       47                Alpha, Reach of Ending Hope   1.55
# ...

# %%
unique_male = male_purchases_pd.groupby("SN").nunique()
unique_males = len(unique_male)
unique_males
# Out:
# 465

# %%
percent_male = unique_males / playercount2
percent_male
# Out:
# 0.8115183246073299

# %%
female_purchases_pd = pymoli2_pd.loc[pymoli2_pd["Gender"] == "Female"]
female_purchases_pd
# Out:
#      Age  Gender  Item ID                                  Item Name  Price  \
# 7     29  Female      169     Interrogator, Blood Blade of the Queen   3.32
# 16    22  Female      123                          Twilight's Carver   1.14
# 17    22  Female       59              Lightning, Etcher of the King   1.65
# 22    11  Female       11                                  Brimstone   2.52
# 29    16  Female       45                        Glinting Glass Edge   2.46
# 30    21  Female      155                  War-Forged Gold Deflector   3.73
# 35    21  Female       13                                   Serenity   1.49
# 41    19  Female      124                             Venom Claymore   2.72
# 50    32  Female       32                                    Orenmir   4.95
# 54    25  Female      101                               Final Critic   4.62
# 58    24  Female       65                  Conqueror Adamantite Mace   1.96
# ...

# %%
unique_female = female_purchases_pd.groupby("SN").nunique()
unique_females = len(unique_female)
unique_females
# Out:
# 100

# %%
percent_female = unique_females / playercount2
percent_female
# Out:
# 0.17452006980802792

# %%
other_pd = playercount2 - (unique_males + unique_females)
other_pd
# Out:
# 8

# %%
other_percent = other_pd / playercount2
other_percent
# Out:
# 0.013961605584642234

# %%
num_male_purchases = male_purchases_pd.count()
num_male_purchases
# Out:
# Age          633
# Gender       633
# Item ID      633
# Item Name    633
# Price        633
# SN           633
# dtype: int64

# %%
avg_male_purchases = male_purchases_pd['Price'].mean()
avg_male_purchases
# Out:
# 2.9505213270142154

# %%
sum_male_purchases = male_purchases_pd['Price'].sum()
sum_male_purchases
# Out:
# 1867.6799999999985

# %%
num_female_purchases = female_purchases_pd.count()
num_female_purchases
# Out:
# Age          136
# Gender       136
# Item ID      136
# Item Name    136
# Price        136
# SN           136
# dtype: int64

# %%
avg_female_purchases = female_purchases_pd['Price'].mean()
avg_female_purchases
# Out:
# 2.815514705882352

# %%
sum_female_purchases = female_purchases_pd['Price'].sum()
sum_female_purchases
# Out:
# 382.90999999999985

# %%
Other_purchases_pd = pymoli2_pd.loc[pymoli2_pd["Gender"] == "Other / Non-Disclosed"]
Other_purchases_pd
# Out:
#      Age                 Gender  Item ID                        Item Name  \
# 177   34  Other / Non-Disclosed      155        War-Forged Gold Deflector
# 209   33  Other / Non-Disclosed      157          Spada, Etcher of Hatred
# 244   21  Other / Non-Disclosed      183              Dragon's Greatsword
# 267   33  Other / Non-Disclosed       65        Conqueror Adamantite Mace
# 276   12  Other / Non-Disclosed      128    Blazeguard, Reach of Eternity
# 298   26  Other / Non-Disclosed      141                       Persuasion
# 329   27  Other / Non-Disclosed       61                         Ragnarok
# 423   32  Other / Non-Disclosed       29          Chaos, Ender of the End
# 593   22  Other / Non-Disclosed      115       Spectral Diamond Doomblade
# 709   34  Other / Non-Disclosed      179  Wolf, Promise of the Moonwalker
# 763   27  Other / Non-Disclosed       48  Rage, Legacy of the Lone Victor
#
#      Price              SN
# 177   3.73       Assassa38
# ...

# %%
num_other_purchases = Other_purchases_pd.count()
num_other_purchases
# Out:
# Age          11
# Gender       11
# Item ID      11
# Item Name    11
# Price        11
# SN           11
# dtype: int64

# %%
avg_other_purchases = Other_purchases_pd['Price'].mean()
avg_other_purchases
# Out:
# 3.2490909090909086

# %%
sum_other_purchases = Other_purchases_pd['Price'].sum()
sum_other_purchases
# Out:
# 35.739999999999995

# %%
dem_purchases_pd = pymoli2_pd.loc[pymoli2_pd["Age"] < 10]
dem_purchases_pd
# Out:
#      Age  Gender  Item ID                                 Item Name  Price  \
# 70     7  Female      158        Darkheart, Butcher of the Champion   3.56
# 121    7    Male      175                Woeful Adamantite Claymore   1.24
# 125    7  Female       10                               Sleepwalker   1.73
# 170    9    Male       71                                    Demise   4.07
# 237    7    Male      121                                  Massacre   3.42
# 260    9    Male       99      Expiration, Warscythe Of Lost Worlds   4.53
# 271    7    Male       77                Piety, Guardian of Riddles   3.68
# 289    8    Male       79                       Alpha, Oath of Zeal   2.88
# 291    7    Male       53                         Vengeance Cleaver   3.70
# 292    7    Male      121                                  Massacre   3.42
# 360    7  Female       21                                 Souleater   3.27
# ...

# %%
dem_count = dem_purchases_pd.count()
dem_count
# Out:
# Age          28
# Gender       28
# Item ID      28
# Item Name    28
# Price        28
# SN           28
# dtype: int64

# %%
bins = [0,9,14,19,24,29,34,39,44,100]
group_names = ['< 10', '10 - 14', '15 - 19 ', '20 - 24', '25 - 29', '30 - 34', '35 - 39', '40-44','45+']

# %%
pymoli2_pd["Age Group"] = pd.cut(pymoli2_pd["Age"], bins, labels=group_names)
pymoli2_pd.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN Age Group
# 0     Aelalis34   35 - 39
# 1        Eolo46   20 - 24
# 2   Assastnya25   30 - 34
# 3  Pheusrical25   20 - 24
# 4        Aela59   20 - 24

# %%
ageitemcount = pymoli2_pd.groupby("Age Group")["Item Name"].count()
ageitemcount
# Out:
# Age Group
# 10 - 14      35
# 15 - 19     133
# 20 - 24     336
# 25 - 29     125
# 30 - 34      64
# 35 - 39      42
# 40-44        16
# 45+           1
# < 10         28
# Name: Item Name, dtype: int64

# %%
ageavgprice = pymoli2_pd.groupby("Age Group")["Price"].mean()
ageavgprice
# Out:
# Age Group
# 10 - 14     2.770000
# 15 - 19     2.905414
# 20 - 24     2.913006
# 25 - 29     2.962640
# 30 - 34     3.082031
# 35 - 39     2.842857
# 40-44       3.189375
# 45+         2.720000
# < 10        2.980714
# Name: Price, dtype: float64

# %%
agetotprice = pymoli2_pd.groupby("Age Group")["Price"].sum()
agetotprice
# Out:
# Age Group
# 10 - 14      96.95
# 15 - 19     386.42
# 20 - 24     978.77
# 25 - 29     370.33
# 30 - 34     197.25
# 35 - 39     119.40
# 40-44        51.03
# 45+           2.72
# < 10         83.46
# Name: Price, dtype: float64

# %%
pd.pivot_table(pymoli2_pd,index=["SN"],values=["Price","Item ID"], aggfunc={"Price":np.sum,"Item ID":len})
# Out:
#                  Item ID  Price
# SN
# Adairialis76           1   2.46
# Aduephos78             3   6.70
# Aeduera68              3   5.80
# Aela49                 1   2.46
# Aela59                 1   1.27
# Aelalis34              2   5.06
# Aelin32                1   3.14
# Aeliriam77             2   6.72
# Aeliriarin93           1   2.04
# Aeliru63               2   8.98
# Aellyria80             1   4.32
# Aellyrialis39          1   3.15
# Aellysup38             1   3.61
# Aelollo59              1   1.55
# Aenarap34              1   1.65
# Aenasu69               1   3.27
# Aeral43                1   2.72
# Aeral85                1   4.25
# Aeral97                1   2.35
# Aeri84                 2   6.60
# Aerillorin70           1   1.88
# Aerithllora36          3  10.45
# Aerithnucal56          2   3.18
# Aerithnuphos61         1   1.69
# Aerithriaphos45        1   2.38
# Aesty51                1   1.82
# Aesur96                1   4.66
# Aethe80                1   2.32
# ...
